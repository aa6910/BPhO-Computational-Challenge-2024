# %% [markdown]
# <a href="https://colab.research.google.com/github/aa6910/BPhO-Computational-Challenge-2024/blob/main/lecture_4_lab_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 4 Lab: Training a Neural Network on MNIST
#
# In this lab, we will implement a simple neural network to classify handwritten digits from the MNIST dataset. We will use PyTorch for this task.
#
# ## 1. Setup and Data Loading
#
# First, let's import the necessary libraries.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %% [markdown]
# ### Load MNIST Dataset
#
# We will use `torchvision.datasets` to download and load the MNIST dataset. The pixel values are transformed to tensors and normalized.

# %%
# Define a transform to normalize the data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)) # Mean and Std Dev of MNIST
])

# Download and load the training data
train_dataset = datasets.MNIST('./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Download and load the test data
test_dataset = datasets.MNIST('./data', train=False, download=True, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)

print(f"Training samples: {len(train_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# %% [markdown]
# ### Visualize Data
#
# Let's look at some examples from the dataset to understand what we are working with.

# %%
images, labels = next(iter(train_loader))
print(f"Image batch shape: {images.shape}")
print(f"Label batch shape: {labels.shape}")

figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    img, label = images[i-1], labels[i-1]
    figure.add_subplot(rows, cols, i)
    plt.title(label.item())
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ### Why Flatten?
#
# As we can see above, the images are 28x28 pixels. However, a standard Multi-Layer Perceptron (MLP) takes a 1D vector as input.
#
# Therefore, before feeding an image into our network, we must **flatten** it from a 2D tensor of shape (28, 28) to a 1D tensor of shape (784,).
#
# Note: Convolutional Neural Networks (CNNs), which we will cover later, can take 2D images directly.

# %% [markdown]
# ## 2. Building the Model
#
# Now we will define our neural network. We'll build a Multilayer Perceptron (MLP) with two hidden layers.

# %% [markdown]
# ### Exercise 1: Define the Layers
#
# In the `__init__` method, define the layers of the network.
# - Input size: 28x28 = 784
# - Hidden layer 1 size: 128
# - Hidden layer 2 size: 64
# - Output size: 10 (digits 0-9)
#
# Use `nn.Linear` for the fully connected layers.

# %% [markdown]
# ### Exercise 2: Define the Forward Pass
#
# In the `forward` method, implement the data flow.
# 1. Flatten the input image tensor (make sure to keep the batch dimension!).
# 2. Pass through the first linear layer and apply ReLU activation.
# 3. Pass through the second linear layer and apply ReLU activation.
# 4. Pass through the output layer.

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        # Exercise 1: Define layers here
        # self.fc1 = ...
        # self.fc2 = ...
        # self.fc3 = ...
        pass # Remove this pass when you add your code

    def forward(self, x):
        # Exercise 2: Implement forward pass
        # x = ...
        return x

# Instantiate the model and move it to the device
model = MLP().to(device)
print(model)

# %% [markdown]
# ## 3. Loss Function and Optimizer
#
# ### Exercise 3: Setup Loss and Optimizer
#
# Choose an appropriate loss function for classification and an optimizer.

# %%
# Exercise 3: Define loss function and optimizer
# criterion = ...
# optimizer = ...

# %% [markdown]
# ## 4. Training Loop
#
# ### Exercise 4: Implement Training Step
#
# Complete the training loop below. For each batch:
# 1. Zero the gradients.
# 2. Perform the forward pass.
# 3. Compute the loss.
# 4. Perform the backward pass.
# 5. Update the parameters.

# %%
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        # Exercise 4: Implement training steps here
        # ...

        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}')

# %% [markdown]
# ## 5. Evaluation
#
# ### Exercise 5: Implement Evaluation
#
# Implement the test function to calculate the accuracy of the model on the test set.

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)

            # Exercise 5: Compute loss and accuracy
            # output = ...
            # test_loss += ...
            # pred = ...
            # correct += ...
            pass # Remove this pass when you add your code

    test_loss /= len(test_loader.dataset)
    print(f'\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} ({100. * correct / len(test_loader.dataset):.0f}%)\n')

# %% [markdown]
# ### Run Training
#
# Now run the training for a few epochs.

# %%
epochs = 5
for epoch in range(1, epochs + 1):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
